# %% [markdown]
# **Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones**
#
# **Edición 2021**
#
# ---
# ## Trabajo práctico entregable - Parte 1

# %%
import io
import matplotlib
import matplotlib.pyplot as plt
import numpy
import pandas as pd
import seaborn

seaborn.set_context('talk')
seaborn.set_theme(style='ticks')

# %% [markdown]
# ## Lectura del dataset
#
# En la notebook *00* se explican los detalles de la siguiente sección.

# %%
url = 'https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/sysarmy_survey_2020_processed.csv'
df = pd.read_csv(url)

# %%
df[:3]
# Out:
#   profile_gender  profile_age work_country                    work_province  \
# 0          Mujer           26    Argentina  Ciudad Autónoma de Buenos Aires
# 1         Hombre           29    Argentina                       Corrientes
# 2          Mujer           22    Argentina  Ciudad Autónoma de Buenos Aires
#
#    profile_years_experience  work_years_in_company  \
# 0                       3.0                    3.0
# 1                       5.0                    2.0
# 2                       2.0                    0.0
#
#    work_years_in_current_position  work_people_in_charge_of  \
# 0                             3.0                         0
# 1                             2.0                         4
# 2                             0.0                         0
#
#   profile_studies_level profile_studies_level_state  ...  \
# 0         Universitario                    En curso  ...
# 1         Universitario                    En curso  ...
# ...

# %% [markdown]
# # Ejercicio 1 - Análisis descriptivo
#
# Responder a la pregunta: **¿Cuáles son los lenguajes de programación asociados a los mejores salarios?**
#
# Para ello:
# 1. Seleccionar las columnas relevantes para analizar.
#
# **Respuesta**
# Para estudiar los lenguajes de programación asociados a los mejores salarios, y responder a la pregunta, se procede a elegir las columnas `tools_programming_languages`, `salary_monthly_NETO`, `work_contract_type`, y `salary_in_usd`.
#
#
# 2. Seleccionar las filas relevantes para analizar. Esto incluye la eliminación de valores extremos y erróneos, pero también puede enfocar el análisis en una sub-población. Por ejemplo, se pueden limitar a personas con un salario mayor que 10000 pesos, o a las personas que trabajan sólo en "Data Science", pero deben justificar su elección y reformular la pregunta inicial de ser necesario.
#
# **Respuesta**
# Observando los datos se pudo apreciar la existencia de valores *NaN* y erróneos, por lo que se procedió a eliminar los valores nulos y los menores a 10000 que existían en la columna `salary_monthly_NETO`.
# Para los valores extremos superiores, se procedió a eliminar los mayores al percentil 99, entendiendo que esto genera un sesgo en la media muestral.
#
#   * Obtener una lista de los lenguajes de programación más populares. Decidir cuántos y cuáles seleccionan para incluir en el análisis.
#
# **Respuesta**
# Se procedió a elegir los lenguajes en función del interés propio del grupo, basado en las experiencias de cada integrante y cuales podrían ser interesantes contrastar.
#
#   * Para cada una de las otras columnas del punto anterior, elegir los rangos o valores que seleccionan para incluir en el análisis.
#
# **Respuesta**
# En el caso de las columnas adicionales, solo se aplica una transformación a los valores de `salary_in_usd`, para poder trabajar con valores *booleanos* en lugar de *strings*.
#
# 3. Seleccionar métricas que ayuden a responder la pregunta, y los métodos para analizarlas. Elegir **UNA** de las siguientes opciones:
#   * Comparar las distribuciones de salario para cada lenguaje utilizando visualizaciones. Como la visualización es el producto final, debe ser clara y mostrar información relevante.
#   * Comparar medidas de estadística descriptiva sobre la distribución de salario para cada lenguaje. Sean creativos, la estadística descriptiva nos permite decir cosas como: "¡El 10% de los mejores sueldos los ganan, en su mayoría, programadores que saben *Kotlin*!" (donde *mayoría* es un término medio engañoso que sólo significa más del 50%). Para comparar múltiples lenguajes, les recomendamos usar también visualizaciones.
#   * Comparar probabilidades. Por ejemplo: "Si sabés *Python* o *Java*, tenés un 30% más de chances de ganar arriba de 100000".
#
# **Respuesta**
# Los resultados, gráficos, y conclusiones, se detallan al final del *notebook*.
#
# Si lo consideran necesario, realicen varias iteraciones. Es decir, si encuentran que las distribuciones de los lenguajes de programación que seleccionaron inicialmente no son muy diferentes, pueden re-hacer el análisis usando sólo los lenguajes de programación que son diferentes.

# %% [markdown]
# ### 1. Selección de Columnas Relevantes

# %%
# Constantes Auxiliares.
lenguajes = 'tools_programming_languages'
neto = 'salary_monthly_NETO'
contrato = 'work_contract_type'
dolares = 'salary_in_usd'

# Selección de Columnas Relevantes.
relevant_columns = [lenguajes, neto, contrato, dolares]

df.columns
# Out:
# Index(['profile_gender', 'profile_age', 'work_country', 'work_province',
#        'profile_years_experience', 'work_years_in_company',
#        'work_years_in_current_position', 'work_people_in_charge_of',
#        'profile_studies_level', 'profile_studies_level_state',
#        'profile_career', 'profile_university',
#        'profile_specialization_courses', 'profile_open_source_contributions',
#        'profile_programming_as_hobby', 'work_role', 'tools_platform',
#        'tools_programming_languages', 'tools_frameworks', 'tools_data_bases',
#        'tools_qa_testing', 'tools_IDEs', 'tools_work_pc_os',
#        'tools_cellphone_os', 'work_on_call_duty', 'salary_on_call_duty_charge',
#        'work_on_call_duty_charge_type', 'work_contract_type',
#        'salary_monthly_BRUTO', 'salary_monthly_NETO', 'salary_in_usd',
#        'salary_satisfaction', 'salary_comparison_last_semester',
#        'salary_has_bonus', 'salary_bonus_tied_to',
# ...

# %% [markdown]
# ### Conteo de frecuencias de los lenguajes de programación
#
# La columna que contiene información sobre los lenguajes de programación utilizados es `tools_programming_languages`. Sus valores son *strings* con los lenguajes seleccionados, separados por comas.

# %%
df[lenguajes][:5]
# Out:
# 0                                              Ninguno
# 1                             HTML, Javascript, Python
# 2                                              Ninguno
# 3    Bash/Shell, C, CSS, HTML, Java, Javascript, PH...
# 4               CSS, HTML, Javascript, SQL, TypeScript
# Name: tools_programming_languages, dtype: object

# %% [markdown]
# ### 2. Selección de Filas Relevantes

# %%
# Gráfico en escala logarítmica, donde se ven los valores (salarios) erróneos menores a 10000.
fig= plt.subplots(figsize=(16, 5))
seaborn.histplot(df[neto], bins=100, color='red', log_scale=True);

# Gráfico donde se ve que existe una diferencia de salarios en función del tipo de contrato.
# Podría ser interesante estudiarlo, o tomar una subpoblación (por ejemplo, Full-Time).
seaborn.catplot(data=df, x=contrato, y=neto, aspect=4, height=4)
plt.xticks(rotation=10);

# %% [markdown]
# Observando el segundo gráfico, notamos que la mayoría de los puntos se encuentran en el intervalo [0 ... 500000].
# Quizás sería adecuado descartar los datos correspondientes a los puntos más distantes del gráfico.

# %%
print(f'Cantidad de filas en el DF: {len(df)}')

print('----------')

# ¿Cuántos NaN existen en la columna de salarios?
print(f'Cantidad de salarios nulos: {df[neto].isna().sum()}')
# Limpieza de valores nulos.
df.dropna(subset=[neto], inplace=True)

# Salario Mínimo para la subpoblación de estudio.
min_salary = 10000
# ¿Cuántos salarios erróneos existen en la columna de salarios?
print(f'Cantidad de salarios <= 10K: {(df[neto] <= min_salary).sum()}')
# Considerando el salario mínimo.
df = df[df[neto] > min_salary]

# Salario Máximo para la subpoblación de estudio (Percentil 99).
max_salary = df[neto].quantile(0.99)
print(f'Percentil 99: {max_salary}')
# ¿Cuántos salarios son anómalos en la columna de salarios?
print(f'Cantidad de salarios anómalos: {(df[neto] >= max_salary).sum()}')
# Considerando el salario del percentil 99.
df = df[df[neto] < max_salary]

print('----------')

# Datos Muestrales (sobre el salario NETO).
df[neto].describe()
# Out:
# Cantidad de filas en el DF: 6095
# ----------
# Cantidad de salarios nulos: 212
# Cantidad de salarios <= 10K: 204
# Percentil 99: 500000.0
# Cantidad de salarios anómalos: 59
# ----------
# count      5620.000000
# mean      91319.909395
# std       61576.111661
# min       10700.000000
# 25%       54000.000000
# 50%       79232.500000
# 75%      106000.000000
# max      490000.000000
# Name: salary_monthly_NETO, dtype: float64

# %%
print(f'Posibles valores de VA: {df[dolares].unique()}')
# Por razones de comodidad, queremos trabajar con valores booleanos en esta columna.
df[dolares] = df[dolares].notna()
print(f'Posibles valores de VA: {df[dolares].unique()}')
# Out:
# Posibles valores de VA: [nan 'Mi sueldo está dolarizado']
# Posibles valores de VA: [False  True]

# %% [markdown]
# #### Determinación de lenguajes más populares
# Las siguientes celdas de código separan estos lenguajes de programación, y cuentan la frecuencia con la que aparecen.
#
# No es necesario entender este código en profundidad, aunque sí es un buen ejercicio.

# %%
def split_languages(languages_str):
    """
    Convert the comma-separated string of languages to a list of string.
    Removes 'ninguno de los anteriores' and 'ninguno' options, spaces, and training commas.
    """
    if not isinstance(languages_str, str):
        return []
    # Remove others options.
    other = 'ninguno de los anteriores'
    languages_str = languages_str.lower().replace(other, '')
    other = 'ninguno'
    languages_str = languages_str.lower().replace(other, '')
    # Split string into list of items.
    # Remove spaces and commas for each item.
    return [lang.strip().replace(',', '') for lang in languages_str.split()]

print(f'Dimensiones del DF: {df.shape}')

# Create a new column with the list of languages.
lenguajes_curados = 'cured_programming_languages'
df[lenguajes_curados] = df[lenguajes].apply(split_languages)

if lenguajes_curados not in relevant_columns:
    relevant_columns.append(lenguajes_curados)

lenguaje = 'programming_language'

# Duplicate each row of df for each programming language mentioned in the response.
# We only include in df_lang the columns we are going to analyze later, so we
# don't duplicate innecesary information.
df_lang = df[lenguajes_curados]\
    .apply(pd.Series).stack()\
    .reset_index(level=-1, drop=True).to_frame()\
    .join(df[relevant_columns])\
    .rename(columns={0: lenguaje})
# Horrible programming style! But a lot of data science code can be written as
# concatenations of functions (pipelines), and there's no elegant way of
# doing that on Python.

print(f'Dimensiones del DF: {df_lang.shape}')
df_lang[:5]
# Out:
# Dimensiones del DF: (5620, 48)
# Dimensiones del DF: (16276, 6)
#   programming_language                        tools_programming_languages  \
# 1                 html                           HTML, Javascript, Python
# 1           javascript                           HTML, Javascript, Python
# 1               python                           HTML, Javascript, Python
# 3           bash/shell  Bash/Shell, C, CSS, HTML, Java, Javascript, PH...
# 3                    c  Bash/Shell, C, CSS, HTML, Java, Javascript, PH...
#
#    salary_monthly_NETO work_contract_type  salary_in_usd  \
# 1              63000.0          Full-Time          False
# 1              63000.0          Full-Time          False
# 1              63000.0          Full-Time          False
# 3             102000.0          Full-Time          False
# 3             102000.0          Full-Time          False
#
#                          cured_programming_languages
# 1                         [html, javascript, python]
# ...

# %% [markdown]
# **Observación**
#
# La cantidad de índices únicos en `df_lang` debería coincidir con la cantidad de programadores en `df` (al menos con los que saben algún lenguaje).
# Ya que un programador puede saber más de un lenguaje de programación y, por lo tanto, aparecería múltiples veces (con índices idénticos) en la tabla obtenida.

# %% [markdown]
# En la columna `programming_language` se encuentra cada lenguaje por separado. Notar que si una respuesta contenía 3 lenguajes, como `"HTML, Javascript, Python"`, la fila ha sido replicada 3 veces. Por ello, hay tres filas con índice 1.

# %%
language_count = df_lang[lenguaje].value_counts().reset_index()\
    .rename(columns={'index': 'language', lenguaje: 'frequency'})

print(f'Cantidad de lenguajes: {len(language_count)}')
language_count[:10]
# Out:
# Cantidad de lenguajes: 195
#      language  frequency
# 0  javascript       2296
# 1         sql       2003
# 2        html       1708
# 3      python       1365
# 4        java       1357
# 5         css       1138
# 6  bash/shell        929
# 7         php        818
# 8        .net        767
# 9  typescript        710

# %% [markdown]
# #### Filtrado de lenguajes relevantes
#
# El siguiente código permite seleccionar sólo las filas donde el valor de la columna `programming_language` se encuentre en la lista `interesting_languages`.

# %%
# Seleccionados según el interés del grupo, en función del conocimiento de dominio, experiencia, etc.
interesting_languages = ['python', '.net', 'java', 'scala', 'typescript', 'go']

# Inicialmente también se incluyó a Haskell, pero posee muy pocos valores para estudiarlo.
print(f'Programadores de Haskell: {(df_lang[lenguaje] == "haskell").sum()}')

filtered_df_lang = df_lang[df_lang[lenguaje].isin(interesting_languages)]
filtered_df_lang[:5]
# Out:
# Programadores de Haskell: 0
#   programming_language                        tools_programming_languages  \
# 1               python                           HTML, Javascript, Python
# 3                 java  Bash/Shell, C, CSS, HTML, Java, Javascript, PH...
# 3               python  Bash/Shell, C, CSS, HTML, Java, Javascript, PH...
# 4           typescript             CSS, HTML, Javascript, SQL, TypeScript
# 5                 java                                   Java, Javascript
#
#    salary_monthly_NETO work_contract_type  salary_in_usd  \
# 1              63000.0          Full-Time          False
# 3             102000.0          Full-Time          False
# 3             102000.0          Full-Time          False
# 4             106000.0          Full-Time          False
# 5              44000.0          Full-Time          False
#
#                          cured_programming_languages
# 1                         [html, javascript, python]
# ...

# %%
# Verificamos la frecuencia de los lenguajes elegidos.
language_count[language_count.language.isin(interesting_languages)]
# Out:
#       language  frequency
# 3       python       1365
# 4         java       1357
# 8         .net        767
# 9   typescript        710
# 11          go        271
# 18       scala        103

# %% [markdown]
# ### 3. Selección de Métricas Relevantes

# %%
# Cantidad de Programadores.
programmers = len(df)
# Mediana del salario NETO.
neto_median = df[neto].median()
# Selección de un salario NETO arbitrario.
neto_x = 100000

print(f'Cantidad programadores: {programmers}')

programmers_over_median = len(df[df[neto] > neto_median])
p_over_median = programmers_over_median / programmers

programmers_over_x = len(df[df[neto] > neto_x])
p_over_x = programmers_over_x / programmers

# Probabilidad de ganar por encima de la mediana (resultado trivial).
print(f'Probabilidad NETO > Mediana ({neto_median}): {p_over_median}')
# Probabilidad de ganar por encima de X = 100000.
print(f'Probabilidad NETO > X ({neto_x}): {p_over_x}')
# Out:
# Cantidad programadores: 5620
# Probabilidad NETO > Mediana (79232.5): 0.5
# Probabilidad NETO > X (100000): 0.28434163701067616

# %%
# ¿Cuáles de los lenguajes seleccionados ganan más que la mediana muestral?
salary_filter = filtered_df_lang[neto] > neto_median
for lang in interesting_languages:
    lang_filter = filtered_df_lang[lenguaje] == lang
    lang_programmers = len(filtered_df_lang[lang_filter])
    print(f'Cantidad programadores de {lang}: {lang_programmers}')
    p_lang = lang_programmers / programmers
    print(f'Probabilidad de utilizar {lang}: {p_lang}')

    lang_over_median = len(filtered_df_lang[lang_filter & salary_filter])
    p_lang_over_median = lang_over_median / lang_programmers
    print(f'Probabilidad NETO > Mediana con {lang}: {p_lang_over_median}')

    print('----------')
# Out:
# Cantidad programadores de python: 1365
# Probabilidad de utilizar python: 0.24288256227758007
# Probabilidad NETO > Mediana con python: 0.6146520146520147
# ----------
# Cantidad programadores de .net: 767
# Probabilidad de utilizar .net: 0.13647686832740213
# Probabilidad NETO > Mediana con .net: 0.4941329856584094
# ----------
# Cantidad programadores de java: 1357
# Probabilidad de utilizar java: 0.24145907473309608
# Probabilidad NETO > Mediana con java: 0.5932203389830508
# ----------
# Cantidad programadores de scala: 103
# Probabilidad de utilizar scala: 0.018327402135231315
# Probabilidad NETO > Mediana con scala: 0.8446601941747572
# ----------
# Cantidad programadores de typescript: 710
# Probabilidad de utilizar typescript: 0.12633451957295375
# Probabilidad NETO > Mediana con typescript: 0.5859154929577465
# ----------
# Cantidad programadores de go: 271
# Probabilidad de utilizar go: 0.04822064056939502
# Probabilidad NETO > Mediana con go: 0.7859778597785978
# ...

# %%
pd.crosstab(index=filtered_df_lang[neto] > neto_median,
            columns=filtered_df_lang[lenguaje],
            normalize='columns')
# Out:
# programming_language      .net        go     java    python    scala  \
# salary_monthly_NETO
# False                 0.505867  0.214022  0.40678  0.385348  0.15534
# True                  0.494133  0.785978  0.59322  0.614652  0.84466
#
# programming_language  typescript
# salary_monthly_NETO
# False                   0.414085
# True                    0.585915

# %% [markdown]
# **Conclusión**
#
# Calculando la probabilidad condicional, parece que los mejores lenguajes (en términos del salario) son *Scala* y *Go*.
# Del otro lado, el lenguaje que sale perjudicado en el análisis es *.net*.
#
# - La probabilidad de ganar por encima de la mediana, dado que se utiliza *Scala* es de **0.84**.
# - La probabilidad de ganar por encima de la mediana, dado que se utiliza *Go* es de **0.79**.
# - La probabilidad de ganar por encima de la mediana, dado que se utiliza *.net* es de **0.49**.
#
# De los lenguajes seleccionados, *Python* y *Java* son los más populares.
# Con un **0.61**, *Python* es el que aparentemente tendría mayor probabilidad de conseguir salarios por encima de la mediana (con respecto a *Java*).

# %%
pd.crosstab(index=filtered_df_lang[neto] > neto_x,
            columns=filtered_df_lang[lenguaje],
            normalize='columns')
# Out:
# programming_language      .net        go      java    python     scala  \
# salary_monthly_NETO
# False                 0.719687  0.424354  0.633751  0.631502  0.359223
# True                  0.280313  0.575646  0.366249  0.368498  0.640777
#
# programming_language  typescript
# salary_monthly_NETO
# False                   0.640845
# True                    0.359155

# %% [markdown]
# **Conclusión**
#
# Realizamos un análisis muy similar al hecho previamente, donde esta vez calculamos la probabilidad condicional en base al valor arbitrario **X = 100000**.
#
# - La probabilidad de ganar por encima de 100000, dado que se utiliza *Scala* es de **0.64**.
# - La probabilidad de ganar por encima de 100000, dado que se utiliza *Go* es de **0.58**.
# - La probabilidad de ganar por encima de 100000, dado que se utiliza *.net* es de **0.28**.

# %% [markdown]
# ## Gráficos

# %%
plt.figure(figsize=(8, 8))

seaborn.boxplot(data=filtered_df_lang,
                x=lenguaje,
                y=neto);

# %% [markdown]
# **Conclusión**
#
# Observando el gráfico anterior se puede notar la superioridad de los salarios de *Scala* y *Go*, frente a los otros lenguajes.
# Al mismo tiempo que la caja de *.net* se ubica levemente debajo de las demás.
# Conclusiones a las que habíamos llegado previamente estudiando las probabilidades condicionales.

# %%
seaborn.catplot(data=filtered_df_lang,
                x=lenguaje,
                y=neto,
                hue=contrato,
                aspect=3, height=5);

# %% [markdown]
# **Conclusión**
#
# Ahora pasamos a otra clase de análisis, sobre el tipo de contrato de trabajo.
# Se pueden deducir a simple vista un par de características.
#
# - Hay mayor cantidad de datos en la categoría *Full-Time* que en las demás.
# - Los datos con *Part-Time* suelen tener un salario bajo, comparado con el resto de puntos.
# - Los puntos que corresponden a las categorías *Freelance* y *Remoto* parecen ser los que más ganan.

# %%
plt.figure(figsize=(20, 12))

seaborn.boxplot(data=filtered_df_lang,
                x=lenguaje,
                y=neto,
                hue=contrato);

# %% [markdown]
# **Conclusión**
#
# El gráfico hace evidente una diferencia importante en el sueldo NETO percibido por alguien con trabajo remoto, y alguien con otro tipo de contrato de trabajo, aunque también se nota mayor dispersión en los salarios.
# Quizás también se puede notar que alguien que trabaja *Freelance* suele percibir una remuneración mayor a los demás contratos restantes.
# Si tomamos *Python*, la mediana de los programadores con trabajo remoto es próxima a los **250000**, mientras que para los demás contratos es próxima (o incluso menor) a los **100000**.
# Por último, nuevamente se nota que los contratos *Part-Time* son los que menor salario poseen.

# %%
plt.figure(figsize=(20, 12))

seaborn.boxplot(data=filtered_df_lang,
                x=lenguaje,
                y=neto,
                hue=dolares);

# %% [markdown]
# **Conclusión**
#
# Agregando aún más evidencia para nuestras suposiciones.
# Se observa que los salarios en dólares son considerablemente mayores que los salarios en pesos, aunque también se aprecia una mayor dispersión de los salarios en dólares.
# Para cada lenguaje, la diferencia de la mediana en pesos con la mediana en dólares parece ser desde 50000 hasta 100000.

# %%
seaborn.catplot(data=filtered_df_lang,
                x=contrato,
                y=neto,
                hue=dolares,
                aspect=5, height=4);

# %% [markdown]
# **Conclusión**
#
# Finalizando, dejamos de lado los lenguajes, y nos concentramos en comparar las clases de contratos.
# A esta altura quizás no sea una sorpresa ver que los contratos con mayor remuneración (*Freelance* y *Remoto*) son los más dolarizados, mientras que los de menor remuneración (*Part-Time*) son los menos dolarizados.
